# %%
from coffea.dataset_tools import rucio_utils
from coffea.dataset_tools.dataset_query import print_dataset_query
from coffea.util import coffea_console
from rich.table import Table

from coffea.dataset_tools.dataset_query import DataDiscoveryCLI

# %%
filesetname = "SingleMuon24B"
dataset_definition = {
    "/ParkingSingleMuon0/Run2024B-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24B","metadata": {"isMC": False}},
    "/ParkingSingleMuon1/Run2024B-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24B","metadata": {"isMC": False}},
    "/ParkingSingleMuon2/Run2024B-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24B","metadata": {"isMC": False}},
    "/ParkingSingleMuon3/Run2024B-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24B","metadata": {"isMC": False}},
    "/ParkingSingleMuon4/Run2024B-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24B","metadata": {"isMC": False}},
    #"/ParkingSingleMuon5/Run2024B-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24B","metadata": {"isMC": False}},
    "/ParkingSingleMuon6/Run2024B-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24B","metadata": {"isMC": False}},
    "/ParkingSingleMuon7/Run2024B-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24B","metadata": {"isMC": False}},
    # "/ParkingSingleMuon*/Run2024C-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24C","metadata": {"isMC": False}},
    # "/ParkingSingleMuon*/Run2024D-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24D","metadata": {"isMC": False}},
    # "/ParkingSingleMuon*/Run2024E-PromptReco-v2/NANOAOD": { "short_name": "SingleMuon24E","metadata": {"isMC": False}},
    # "/ParkingSingleMuon*/Run2024F-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24F","metadata": {"isMC": False}},
    # "/ParkingSingleMuon*/Run2024G-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24G","metadata": {"isMC": False}},
    # "/ParkingSingleMuon*/Run2024H-PromptReco-v1/NANOAOD": { "short_name": "SingleMuon24H","metadata": {"isMC": False}},
    # "/ParkingSingleMuon*/Run2024I-PromptReco-v2/NANOAOD": { "short_name": "SingleMuon24I","metadata": {"isMC": False}},
}

# %%
ddc = DataDiscoveryCLI()
ddc.do_regex_sites(r"T3_US_FNALLPC")
ddc.load_dataset_definition(dataset_definition, replicas_strategy="round-robin")
# Out:
# New sites regex: T3_US_FNALLPC
# Processing query: /ParkingSingleMuon0/Run2024B-PromptReco-v1/NANOAOD
# Output()
#       Query: /ParkingSingleMuon0/Run2024B-PromptReco-v1/NANOAOD
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Name               ┃ Tag                                ┃ Selected ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ ParkingSingleMuon0 │ (1) Run2024B-PromptReco-v1/NANOAOD │    N     │
# └────────────────────┴────────────────────────────────────┴──────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Use the command select to selected the datasets
# Selected datasets:
# - (1) /ParkingSingleMuon0/Run2024B-PromptReco-v1/NANOAOD
# Processing query: /ParkingSingleMuon1/Run2024B-PromptReco-v1/NANOAOD
# Output()
#       Query: /ParkingSingleMuon1/Run2024B-PromptReco-v1/NANOAOD
# ...

# %%
ddc.do_list_selected()
# Out:
# Selected datasets:
#                                        Selected datasets
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Index ┃ Dataset                                            ┃ Replicas selected ┃ N. of files ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ 1     │ /ParkingSingleMuon0/Run2024B-PromptReco-v1/NANOAOD │         Y         │     37      │
# │ 2     │ /ParkingSingleMuon1/Run2024B-PromptReco-v1/NANOAOD │         Y         │     39      │
# │ 3     │ /ParkingSingleMuon2/Run2024B-PromptReco-v1/NANOAOD │         Y         │     40      │
# │ 4     │ /ParkingSingleMuon3/Run2024B-PromptReco-v1/NANOAOD │         Y         │     39      │
# │ 5     │ /ParkingSingleMuon4/Run2024B-PromptReco-v1/NANOAOD │         Y         │     39      │
# │ 6     │ /ParkingSingleMuon6/Run2024B-PromptReco-v1/NANOAOD │         Y         │     38      │
# ...

# %%
ddc.do_save(f"{filesetname}_replicas_info.json")
# Out:
# File SingleMuon24B_replicas_info.json saved!

# %%
fileset_total = ddc.do_preprocess(
    output_file=f"preproc_{filesetname}",
    step_size=100_000,
    align_to_clusters=False,
    scheduler_url=None,
)
